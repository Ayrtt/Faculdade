# %% [markdown]
# #Questão 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Questão 2
#
# 1.   Se X4 >= 135,2: \
#     1.1: Se X3 == Sim: y = 0 \
#     1.2: Se X3 == Não: y = 0
# 2.   Se X4 < 135,2: \
#     2.1: Se X2 == Baixo: y = 0 \
#     2.2: Se X2 == Alto: y = 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## a)
#
# \begin{align}
# Entropy(7+,5-) &= -(7/12) log_2(7/12)-(5/12)log_2(5/12) \\
# Entropy(7+,5-) &= -(0,5833)*(-0,7776)-(0,4166)*(-1,2632) \\
# Entropy(7+,5-) &= 0,4535-(-0,5262) \\
# Entropy(conj) &= 0,9797
# \end{align}

# %% [markdown]
# ## b)
#
# - p(+|a2=T) = 2/4
# - p(-|a2=T) = 2/4
#
#
# \begin{align}
# Ent(a2=T) &= -(2/4) log_2(2/4)-(2/4)log_2(2/4) \\
# Ent(a2=T) &= -(0,5)*(-1)-(0,5)*(-1) \\
# Ent(a2=T) &= 1
# \end{align}

# %% [markdown]
# - p(+|a2=F) = 1/2
# - p(-|a2=F) = 1/2
#
#
# \begin{align}
# Ent(a2=F) &= -(1/2) log_2(1/2)-(1/2)log_2(1/2) \\
# Ent(a2=F) &= -(0,5)*(-1)-(0,5)*(-1) \\
# Ent(a2=F) &= 1
# \end{align}

# %% [markdown]
# \begin{equation}
# Info(a2) = 4/6*1+2/6*1=1
# \end{equation}
#
# \begin{align}
# Ganho(a2) &= Ent(conj)-Info(a2) \\
# Ent(a2=T) &= 0,9797-1 \\
# Ent(a2=T) &= -0,0203
# \end{align}
